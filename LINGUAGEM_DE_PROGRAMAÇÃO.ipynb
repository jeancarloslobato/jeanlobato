# %% [markdown]
# <a href="https://colab.research.google.com/github/jeancarloslobato/jeanlobato/blob/main/LINGUAGEM_DE_PROGRAMA%C3%87%C3%83O.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #U1_A1

# %%
# Nosso primeiro trabalho

print ("Hello Word")
# Out:
# Hello Word

# %%
#2 Criando Variaveis de tipos diferentes

x = 10
nome = "jean"
nota = 8,75
fez_inscrição = True

# %%
print (x)
print (nome)
print (nota)
print (fez_inscrição)
# Out:
# 10
# jean
# (8, 75)
# True

# %%
print (type(x))
print (type(nome))
print (type(nota))
print (type(fez_inscrição))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'tuple'>
# <class 'bool'>

# %%
nome = input ("digite seu nome:")
# Out:
# digite seu nome:jean

# %%
print (f"olá {nome}, Bem vindo a disciplina de programação")
# Out:
# olá jean, Bem vindo a disciplina de programação

# %%
nota_1 = int (input ("digite a nota 1: "))
nota_2 = int (input ("digite a nota 2: "))
nota_3 = int (input ("digite a nota 3: "))
nota_4 = int (input ("digite a nota 4: "))
# Out:
# digite a nota 1: 5
# digite a nota 2: 6
# digite a nota 3: 7
# digite a nota 4: 8

# %%
media = nota_1+nota_2+nota_3+nota_4/4

# %%
print(meida)
# Out:
# 20.0

# %%
if media >= 6:
 situação = "aprovado"
else:
 situação = "reprovado"

# %%
print (situação)
# Out:
# aprovado

# %% [markdown]
# #U1_A2

# %%
print (10>5)
# Out:
# True

# %%
#Quardando Informações
Idade = 20
e_maior_de_idade = Idade >= 18
print (e_maior_de_idade)
# Out:
# True

# %%
print (True and True)
# Out:
# True

# %%
print(True and False)
# Out:
# False

# %%
idade = int (input ("digite sua idade: "))
if idade < 18:
  print ("menor de idade")
elif idade >= 18 and idade <65:
  print ( "adulto")
else:
  print ("idoso")
# Out:
# digite sua idade: 66
# idoso

# %%
idade = int (input ("digite sua idade: "))
if idade < 18:
  print ("recomendamos o filme infatil 1")
elif idade >= 12 and idade <18:
  print ("recomendamos o filme infatil 2")
else:
  print ("recomendamos o filme infatil 3")

  quantidade_de_ingresso = 10
  if quantidade_de_ingresso > 0:
    print ("ingresso disponivel, Divirta-se no Cinema")
  else:
    print ("Desculpe, todos os ingressos foram vendidos")
# Out:
# digite sua idade: 19
# recomendamos o filme infatil 3
# ingresso disponivel, Divirta-se no Cinema

# %% [markdown]
# #U1_A3

# %%
numeros = [1,2,3,4,5,6,7]

for numeros in numeros:
 print("%f camiseta: {numeros}")
# Out:
# %f camiseta: {numeros}
# %f camiseta: {numeros}
# %f camiseta: {numeros}
# %f camiseta: {numeros}
# %f camiseta: {numeros}
# %f camiseta: {numeros}
# %f camiseta: {numeros}

# %%
print (type(numeros))
# Out:
# <class 'int'>

# %%
numero = int (input ("digite um numero (ou 0 para sair): "))

while numero !=0:
  if numero % 2 == 0:
    print ("o numero é par")
  else:
    print ("o numero é impar")
  numero = int (input ("digite um numero (ou 0 para sair): "))
# Out:
# digite um numero (ou 0 para sair): 5
# o numero é impar
# digite um numero (ou 0 para sair): 3
# o numero é impar
# digite um numero (ou 0 para sair): 2
# o numero é par
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2323/374712143.py in <cell line: 0>()
#       6   else:
#       7     print ("o numero é impar")
# ----> 8   numero = int (input ("digite um numero (ou 0 para sair): "))
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
# ...

# %%
for x in range (1,15,3):
  print(x)
# Out:
# 1
# 4
# 7
# 10
# 13

# %%
filmes = {"Filme 1", "Filme 2", "Filme 3", "Filme 4", "FIlme 5"}
print("Bem vindo a classificação do filme")
print("Você tem cinco filmes para classificar")
print("digite '0' a qualquer momento para parar.\n")

for filme_item in filmes:
  classificacao_str = input(f" como você classifica '{filme_item}' de 1 a 5 (ou 0 para parar):")

  if classificacao_str == '0':
    print ("Que pena")
    break

  try:
    classificacao = int(classificacao_str)
  except ValueError:
    print("Classificação inválida. Por favor, digite um número.")
    continue

  if classificacao < 1 or classificacao > 5:
    print (f"Classificação inválida")
  else:
    print(f"Você classificou '{filme_item}' com a '{classificacao}' estrelas.\n")

print("Obrigado por classificar os filmes")
# Out:
# Bem vindo a classificação do filme
# Você tem cinco filmes para classificar
# digite '0' a qualquer momento para parar.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2323/3219719577.py in <cell line: 0>()
#       5
#       6 for filme_item in filmes:
# ----> 7   classificacao_str = input(f" como você classifica '{filme_item}' de 1 a 5 (ou 0 para parar):")
#       8
#       9   if classificacao_str == '0':
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ...

# %% [markdown]
# #U1_A4

# %%
numero = [1,2,3,4,5]

comprimento = len(numero)
print (comprimento)
# Out:
# 5

# %%
range (5)
# Out:
# range(0, 5)

# %%
def soma(a,b):
  resultado = a+b
  return resultado

# %%
resultado_soma = soma (5,6)

# %%
print(resultado_soma)
# Out:
# 11

# %%
def e_par(numero):
  if numero % 2 == 0:
    return True
  else:
    return False

# %%
numero= 312343242341321342344234542432389748328462
teste = e_par(numero)
print (teste)
# Out:
# True

# %%
media = 8.232654655
arrendondar_media = lambda media: round(media,2)
print (arrendondar_media)
# Out:
# <function <lambda> at 0x7b615fe0ed40>

# %%
media_arredondada = arrendondar_media(media)
print(media_arredondada)
# Out:
# 8.23

# %% [markdown]
# #U2_A2

# %%
meu_conjunto = set()

# %%
meu_conjunto.add(10)

# %%
meu_conjunto.add(20)
meu_conjunto.add(30)

# %%
meu_conjunto.add(10)

# %%
meu_conjunto
# Out:
# {10, 20, 30}

# %%
elemento = 20
if elemento in meu_conjunto:
  print(f"o elemento {elemento} está no conjunto")
else:
  print(f"o elemento {elemento} não está no conjunto")
# Out:
# o elemento 20 está no conjunto

# %%
numero_com_repeticao = [1,2,2,2,3,3,3,4,4,4,4]

# %%
unicos = set(numero_com_repeticao)

# %%
numero_com_repeticao
# Out:
# [1, 2, 2, 2, 3, 3, 3, 4, 4, 4, 4]

# %%
unicos
# Out:
# {1, 2, 3, 4}

# %%
dici_1 = {}

# %%
dici_1 ["nome"] = "jean"
dici_1 ["idade"] = 23

# %%
dici_1
# Out:
# {'nome': 'jean', 'idade': 23}

# %%
dici_2 = {"nome": "Jean", "idade": 23}

# %%
dici_2
# Out:
# {'nome': 'Jean', 'idade': 23}

# %% [markdown]
# #U2_A3

# %%
class Pessoa:
  def __init__(self, nome, idade, genero):
    self.nome = nome
    self.idade = idade
    self.genero = genero

  def falar_nome(self):
    print(f"Olá, meu nome é {self.nome}")

  def aniversario(self):
    self.idade += 1

# %%
# A função 'aniversario' foi movida para dentro da classe Pessoa.

# %%
pessoa1 = Pessoa("jean", 23, "masculino")

# %%
print(pessoa1.falar_nome())
# Out:
# Olá, meu nome é jean
# None

# %%
# Chamada o método aniversario para aumentar a idade
pessoa1.aniversario()
print(f"Nova idade: {pessoa1.idade}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_4129/628507429.py in <cell line: 0>()
#       1 # Chamada o método aniversario para aumentar a idade
# ----> 2 pessoa1.aniversario()
#       3 print(f"Nova idade: {pessoa1.idade}")
#
# AttributeError: 'Pessoa' object has no attribute 'aniversario'

# %% [markdown]
# ### Definição Completa da Classe `Pessoa` e Instanciação do Objeto

# %%
class Pessoa:
  def __init__(self, nome, idade, genero):
    self.nome = nome
    self.idade = idade
    self.genero = genero

  def falar_nome(self):
    return f"Olá, meu nome é {self.nome}"

  def aniversario(self):
    self.idade += 1
    print(f"Parabéns! {self.nome} completou {self.idade} anos.")

# Instanciando o objeto (agora a classe já contém o método aniversario)
pessoa1 = Pessoa("jean", 23, "masculino")

# Exibindo o nome
print(pessoa1.falar_nome())

# Chamando o método aniversario
pessoa1.aniversario()

# Verificando a nova idade
print(f"Nova idade da pessoa1: {pessoa1.idade}")
# Out:
# Olá, meu nome é jean
# Parabéns! jean completou 24 anos.
# Nova idade da pessoa1: 24

# %%
#3 Herança - classe-pai Animal e duas classes-filhas
class Animal:
  def __init__(self, nome, idade):
    self.nome = nome
    self.idade = idade

def fazer_barulho(self):
  pass #método "vazio" quem será sobrescrito pelas filhas

# %%
class cachorro(Animal):
  def fazer_barulho(self):
    return "latir"

# %%
class Gato(Animal):
  def fazer_barulho(self):
    return "Miar"

# %%
# 4. Criando e usando objetos das classes.filhas
rex = cachorro("Rex", 3)
Whisker = Gato("Whisker", 2)

# %%
print(f"{rex.nome} faz: {rex.fazer_barulho()}")
print(f"{Whisker.nome} faz: {Whisker.fazer_barulho()}")
# Out:
# Rex faz: latir
# Whisker faz: Miar

# %% [markdown]
# #U2_A4

# %%
import matplotlib.pyplot as plt


# Dados de exemplo

meses = ['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio']

vendas = [120, 90, 150, 80, 200]


# Criar um gráfico de barras

plt.bar(meses, vendas, color='royalblue')


# Adicionar rótulos aos eixos

plt.xlabel('Mês')

plt.ylabel('Vendas (em unidades)')


# Adicionar um título ao gráfico

plt.title('Vendas Mensais')


# Mostrar o gráfico

plt.show()

# %% [markdown]
# #ENCERRAMENTO U2

# %%
import matplotlib.pyplot as plt

# %%
class produto:
  def __init__(self, nome, preco, categoria, estoque):
    self.nome = nome
    self.preco = preco
    self.categoria = categoria
    self.estoque = estoque

#Denifindos como o produto aparece quando é impresso

  def __str__(self):
    return (f"{self.nome} R$ {self.preco:.2f} | "
            f"{self.categoria} | "
            f"{self.estoque}")

# %%
catalogo =[]
categorias = []

# %%
def Adicionar_produto (nome, preco, categoria, estoque):
  novo_produto = produto(nome, preco, categoria, estoque)
  catalogo.append(novo_produto)
  if categoria not in categorias:
    categorias.append(categoria)
  print(f"O produto {novo_produto.nome} foi adicionado ao catalogo")

# %%
def listar_catalogo():
  print("\n--- Catalogo da Minhaloja ---")
  for produto in catalogo:
    print(produto)

# %%
# Redefinindo a função corretamente para evitar o conflito no ambiente
def Adicionar_produto(nome, preco, categoria, estoque):
  novo_produto = produto(nome, preco, categoria, estoque)
  catalogo.append(novo_produto)
  if categoria not in categorias:
    categorias.append(categoria)
  print(f"O produto {novo_produto.nome} foi adicionado ao catalogo")

# Cadastrar Produtos
Adicionar_produto("Notebook", 3500.00, "informatica", 12)
Adicionar_produto("Smartphone", 2200.00, "informatica", 18)
Adicionar_produto("cafeteira", 280.00, "eletrodoméstico", 10)
Adicionar_produto("Tablet", 1500.00, "informatica", 30)
Adicionar_produto("teclado", 200.00, "acessório", 20)

listar_catalogo()
# Out:
# O produto Notebook foi adicionado ao catalogo
# O produto Smartphone foi adicionado ao catalogo
# O produto cafeteira foi adicionado ao catalogo
# O produto Tablet foi adicionado ao catalogo
# O produto teclado foi adicionado ao catalogo
#
# --- Catalogo da Minhaloja ---
# Notebook R$ 3500.00 | informatica | 12
# Notebook R$ 3500.00 | informatica | 12
# Notebook R$ 3500.00 | informatica | 12
# Notebook R$ 3500.00 | informatica | 12
# Notebook R$ 3500.00 | informatica | 12
# Notebook R$ 3500.00 | informatica | 12
# Notebook R$ 3500.00 | informatica | 12
# Smartphone R$ 2200.00 | informatica | 18
# cafeteira R$ 280.00 | eletrodoméstico | 10
# Tablet R$ 1500.00 | informatica | 30
# teclado R$ 200.00 | acessório | 20
# Notebook R$ 3500.00 | informatica | 12
# Smartphone R$ 2200.00 | informatica | 18
# cafeteira R$ 280.00 | eletrodoméstico | 10
# Tablet R$ 1500.00 | informatica | 30
# teclado R$ 200.00 | acessório | 20

# %%
#Grafico por categoria
categorias_unicas = list(set(categorias))
quantidade_por_categoria = [categorias.count(categoria) for categoria in categorias_unicas]

plt.bar(categorias_unicas, quantidade_por_categoria)
plt.xlabel
# Out:
# <function matplotlib.pyplot.xlabel(xlabel: 'str', fontdict: 'dict[str, Any] | None' = None, labelpad: 'float | None' = None, *, loc: "Literal['left', 'center', 'right'] | None" = None, **kwargs) -> 'Text'>

# %%
# Adicionando os valores em cima de cada barra correspondente ao total de itens por categoria
for i, valor in enumerate(quantidade_por_categoria):
  plt.text(i, valor, str(valor), ha='center', va='bottom')

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
